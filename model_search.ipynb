# %%
import pandas as pd
import pycaret

# %%
#path="./saved_data/1_to_train.pkl"#to train the first model
path="./saved_data/2_to_train.pkl"#to train the second model

# %%
datadf = pd.read_pickle(path)

# %%
from pycaret.classification import *

# %%
clf = setup(
    data=datadf, 
    target='target',
    train_size=0.8,
    normalize=True,
)
# Out:
# <style  type="text/css" >
# #T_8fcc9_row29_col1,#T_8fcc9_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_8fcc9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8fcc9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8fcc9_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_8fcc9_row0_col1" class="data row0 col1" >1536</td>
#             </tr>
#             <tr>
#                         <th id="T_8fcc9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8fcc9_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_8fcc9_row1_col1" class="data row1 col1" >target</td>
#             </tr>
# ...

# %%
compare_models(sort='AUC')
# Out:
# <style  type="text/css" >
#     #T_d302a_ th {
#           text-align: left;
# ...

# %%
m=create_model('lr')
# Out:
# <style  type="text/css" >
# #T_c4b23_row10_col0,#T_c4b23_row10_col1,#T_c4b23_row10_col2,#T_c4b23_row10_col3,#T_c4b23_row10_col4,#T_c4b23_row10_col5,#T_c4b23_row10_col6{
#             background:  yellow;
#         }</style><table id="T_c4b23_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
# ...

# %%
tuned_m=tune_model(m,n_iter=100)
# Out:
# <style  type="text/css" >
# #T_7db7b_row10_col0,#T_7db7b_row10_col1,#T_7db7b_row10_col2,#T_7db7b_row10_col3,#T_7db7b_row10_col4,#T_7db7b_row10_col5,#T_7db7b_row10_col6{
#             background:  yellow;
#         }</style><table id="T_7db7b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
# ...

# %%
tuned_m
# Out:
# LogisticRegression(C=6.451000000000001, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=1000, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1536, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
